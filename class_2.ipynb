# %%
import pandas as pd

# %%
df2 = pd.read_csv('/Users/justinsheng/Library/CloudStorage/OneDrive-UniversityofToronto/VS_code/dataset/customers-1.csv')

# %%
df2
# Out:
#       id           cust_name  num_products province  len_relationship
# 0   1001      Johnny Awesome             3       ON                 1  \
# 1   1002          Bob Marley             4       ON                 1
# 2   1004        Taylor Swift             2       AB                 2
# 3   1101          James Dean             3       BC                 3
# 4   1006       Stephen Smith             5       ON                 4
# 5   1014       Delilah Avery             2       AB                 3
# 6   1254        Johnson Cory             1       AB                 4
# 7   1285          Maria Alva             5       ON                 2
# 8   1354        Jessica Fast             4       BC                 5
# 9   1005  Mariah Anita Smith             2       BC                 3
# 10  1008      Robert Optimus             3       MB                10
# 11  1585        Steven Prime             5       AB                 2
# ...

# %%
df2 = df2.rename(columns={'id':'customer_id'})
df2
# Out:
#                       cust_name  num_products province  len_relationship
# customer_id
# 1001             Johnny Awesome             3       ON                 1  \
# 1002                 Bob Marley             4       ON                 1
# 1004               Taylor Swift             2       AB                 2
# 1101                 James Dean             3       BC                 3
# 1006              Stephen Smith             5       ON                 4
# 1014              Delilah Avery             2       AB                 3
# 1254               Johnson Cory             1       AB                 4
# 1285                 Maria Alva             5       ON                 2
# 1354               Jessica Fast             4       BC                 5
# 1005         Mariah Anita Smith             2       BC                 3
# 1008             Robert Optimus             3       MB                10
# 1585               Steven Prime             5       AB                 2
# ...

# %%
df2.set_index('cust_category')
# Out:
#                            cust_name  num_products province  len_relationship
# cust_category
# wealth                Johnny Awesome             3       ON                 1
# personal_banking          Bob Marley             4       ON                 1
# hnw                     Taylor Swift             2       AB                 2
# wealth                    James Dean             3       BC                 3
# hnw                    Stephen Smith             5       ON                 4
# personal_banking       Delilah Avery             2       AB                 3
# hnw                     Johnson Cory             1       AB                 4
# wealth                    Maria Alva             5       ON                 2
# personal_banking        Jessica Fast             4       BC                 5
# personal_banking  Mariah Anita Smith             2       BC                 3
# hnw                   Robert Optimus             3       MB                10
# ...

# %%
df2.set_index('customer_id', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/jh/lwh9h51151s6_693cw5_28cr0000gn/T/ipykernel_27427/189526526.py in ?()
# ----> 1 df2.set_index('customer_category', inplace=True)
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5865                     if not found:
#    5866                         missing.append(col)
#    5867
#    5868         if missing:
# -> 5869             raise KeyError(f"None of {missing} are in the columns")
#    5870
#    5871         if inplace:
#    5872             frame = self
#
# KeyError: "None of ['customer_category'] are in the columns"

# %%
df2.columns
# Out:
# Index(['cust_name', 'num_products', 'province', 'len_relationship',
#        'cust_category'],
#       dtype='object')

# %%
df2.axes
# Out:
# [Index([1001, 1002, 1004, 1101, 1006, 1014, 1254, 1285, 1354, 1005, 1008, 1585,
#         1475],
#        dtype='int64', name='customer_id'),
#  Index(['cust_name', 'num_products', 'province', 'len_relationship',
#         'cust_category'],
#        dtype='object')]

# %%
df2.sort_index(axis=1, ascending=True)
# Out:
#                 cust_category           cust_name  len_relationship
# customer_id
# 1001                   wealth      Johnny Awesome                 1  \
# 1002         personal_banking          Bob Marley                 1
# 1004                      hnw        Taylor Swift                 2
# 1101                   wealth          James Dean                 3
# 1006                      hnw       Stephen Smith                 4
# 1014         personal_banking       Delilah Avery                 3
# 1254                      hnw        Johnson Cory                 4
# 1285                   wealth          Maria Alva                 2
# 1354         personal_banking        Jessica Fast                 5
# 1005         personal_banking  Mariah Anita Smith                 3
# 1008                      hnw      Robert Optimus                10
# 1585                   wealth        Steven Prime                 2
# 1475         personal_banking   Stephanie Element                 5
#
# ...

# %%
df2.columns
# Out:
# Index(['cust_name', 'num_products', 'province', 'len_relationship',
#        'cust_category'],
#       dtype='object')

# %%
df2.cust_name
# Out:
# customer_id
# 1001        Johnny Awesome
# 1002            Bob Marley
# 1004          Taylor Swift
# 1101            James Dean
# 1006         Stephen Smith
# 1014         Delilah Avery
# 1254          Johnson Cory
# 1285            Maria Alva
# 1354          Jessica Fast
# 1005    Mariah Anita Smith
# 1008        Robert Optimus
# 1585          Steven Prime
# 1475     Stephanie Element
# Name: cust_name, dtype: object

# %%
list1 = [1,2,3,4]

# %%
list1
# Out:
# [1, 2, 3, 4]

# %%
df2.loc[1001]
# Out:
# cust_name           Johnny Awesome
# num_products                     3
# province                        ON
# len_relationship                 1
# cust_category               wealth
# Name: 1001, dtype: object

# %%
df2.loc[[1001,1101],['province', 'cust_name']]
# Out:
#             province       cust_name
# customer_id
# 1001              ON  Johnny Awesome
# 1101              BC      James Dean

# %%
df2['num_products'] == 2
# Out:
# customer_id
# 1001    False
# 1002    False
# 1004     True
# 1101    False
# 1006    False
# 1014     True
# 1254    False
# 1285    False
# 1354    False
# 1005     True
# 1008    False
# 1585    False
# 1475     True
# Name: num_products, dtype: bool

# %%
df2[df2['num_products'] == 2 ]
# Out:
#                       cust_name  num_products province  len_relationship
# customer_id
# 1004               Taylor Swift             2       AB                 2  \
# 1014              Delilah Avery             2       AB                 3
# 1005         Mariah Anita Smith             2       BC                 3
# 1475          Stephanie Element             2       ON                 5
#
#                 cust_category
# customer_id
# 1004                      hnw
# 1014         personal_banking
# 1005         personal_banking
# 1475         personal_banking

# %%
df2[(df2['province']=='AB')| (df2['province'] == 'ON')]
# Out:
#                      cust_name  num_products province  len_relationship
# customer_id
# 1001            Johnny Awesome             3       ON                 1  \
# 1002                Bob Marley             4       ON                 1
# 1004              Taylor Swift             2       AB                 2
# 1006             Stephen Smith             5       ON                 4
# 1014             Delilah Avery             2       AB                 3
# 1254              Johnson Cory             1       AB                 4
# 1285                Maria Alva             5       ON                 2
# 1585              Steven Prime             5       AB                 2
# 1475         Stephanie Element             2       ON                 5
#
#                 cust_category
# customer_id
# 1001                   wealth
# 1002         personal_banking
# 1004                      hnw
# 1006                      hnw
# 1014         personal_banking
# 1254                      hnw
# ...

# %%
df2[df2.index.isin([1004,1101])]
# Out:
#                 cust_name  num_products province  len_relationship
# customer_id
# 1004         Taylor Swift             2       AB                 2  \
# 1101           James Dean             3       BC                 3
#
#             cust_category
# customer_id
# 1004                  hnw
# 1101               wealth

# %%
df2[(df2['province']=='ON') & (df2['cust_category'] == 'personal_banking')]
# Out:
#                      cust_name  num_products province  len_relationship
# customer_id
# 1002                Bob Marley             4       ON                 1  \
# 1475         Stephanie Element             2       ON                 5
#
#                 cust_category
# customer_id
# 1002         personal_banking
# 1475         personal_banking
