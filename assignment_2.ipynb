# %%
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats

# %%
df = pd.read_csv('/Users/justinsheng/Library/CloudStorage/OneDrive-UniversityofToronto/Justin/Schulich_2023-2024/MBAN6110/experiment_dataset.csv')

# %%
df.describe(include='all')
# Out:
#          Unnamed: 0          Age   Location   Device  Variant   Time Spent
# count   1000.000000  1000.000000       1000     1000     1000  1000.000000  \
# unique          NaN          NaN          3        3        3          NaN
# top             NaN          NaN  Location2  Device3  Control          NaN
# freq            NaN          NaN        343      346      340          NaN
# mean     499.500000    40.715000        NaN      NaN      NaN    22.713345
# std      288.819436    13.655557        NaN      NaN      NaN     5.479292
# min        0.000000    18.000000        NaN      NaN      NaN     7.114806
# 25%      249.750000    28.000000        NaN      NaN      NaN    19.216608
# 50%      499.500000    41.000000        NaN      NaN      NaN    22.506707
# 75%      749.250000    53.000000        NaN      NaN      NaN    26.255950
# max      999.000000    64.000000        NaN      NaN      NaN    39.395770
#
#                 CTR
# count   1000.000000
# unique          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Age         1000 non-null   int64
#  2   Location    1000 non-null   object
#  3   Device      1000 non-null   object
#  4   Variant     1000 non-null   object
#  5   Time Spent  1000 non-null   float64
#  6   CTR         1000 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 54.8+ KB

# %%
df
# Out:
#      Unnamed: 0  Age   Location   Device    Variant  Time Spent       CTR
# 0             0   62  Location2  Device2    Control   13.928669  0.084776
# 1             1   18  Location1  Device1  Variant B   11.310518  0.096859
# 2             2   21  Location2  Device1  Variant B   24.842100  0.097630
# 3             3   21  Location1  Device3  Variant B   20.061300  0.109783
# 4             4   57  Location1  Device2  Variant B   34.495503  0.068579
# ..          ...  ...        ...      ...        ...         ...       ...
# 995         995   39  Location2  Device2  Variant B   17.252030  0.092211
# 996         996   38  Location3  Device2    Control   30.075898  0.078151
# 997         997   60  Location2  Device3    Control   31.929223  0.125213
# 998         998   35  Location2  Device2  Variant B   14.680299  0.095423
# 999         999   55  Location1  Device1  Variant B   25.803169  0.166688
#
# [1000 rows x 7 columns]

# %%
sns.lmplot(data = df, x='Age', y='CTR', hue = 'Location')

# %%
sns.lmplot(data = df, x='Age', y='CTR', hue = 'Device')

# %%
sns.lmplot(data = df, x='Age', y='CTR', hue = 'Variant')

# %%
sns.lmplot(data = df, x='Age', y='Time Spent', hue = 'Location')

# %%
sns.lmplot(data = df, x='Age', y='Time Spent', hue = 'Device')

# %%
sns.lmplot(data = df, x='Age', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df, x='CTR', y='Time Spent', hue = 'Location')

# %%
sns.lmplot(data = df, x='CTR', y='Time Spent', hue = 'Device')

# %%
sns.lmplot(data = df, x='CTR', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Device'] == 'Device1'], x='CTR', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Device'] == 'Device2'], x='CTR', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Device'] == 'Device3'], x='CTR', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Location'] == 'Location1'], x='CTR', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Location'] == 'Location2'], x='CTR', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Location'] == 'Location3'], x='CTR', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Location'] == 'Location1'], x='Age', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Location'] == 'Location2'], x='Age', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Location'] == 'Location3'], x='Age', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Device'] == 'Device1'], x='Age', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Device'] == 'Device2'], x='Age', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Device'] == 'Device3'], x='Age', y='Time Spent', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Device'] == 'Device1'], x='Age', y='CTR', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Device'] == 'Device2'], x='Age', y='CTR', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Device'] == 'Device3'], x='Age', y='CTR', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Location'] == 'Location1'], x='Age', y='CTR', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Location'] == 'Location2'], x='Age', y='CTR', hue = 'Variant')

# %%
sns.lmplot(data = df[df['Location'] == 'Location3'], x='Age', y='CTR', hue = 'Variant')

# %%
Control_CTR = df[df['Variant'] == 'Control']['CTR']
VA_CTR = df[df['Variant'] == 'Variant A']['CTR']

t_stat, p_val = stats.ttest_ind(Control_CTR, VA_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -13.829424737499187
# P-value: 1.9602781373243157e-38

# %%
Control_CTR = df[df['Variant'] == 'Control']['CTR']
VB_CTR = df[df['Variant'] == 'Variant B']['CTR']

t_stat, p_val = stats.ttest_ind(Control_CTR, VB_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -6.4718143491783255
# P-value: 1.8743198199982106e-10

# %%
Control_TS = df[df['Variant'] == 'Control']['Time Spent']
VA_TS = df[df['Variant'] == 'Variant A']['Time Spent']

t_stat, p_val = stats.ttest_ind(Control_TS, VA_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -12.142363487472364
# P-value: 8.488565644996449e-31

# %%
Control_TS = df[df['Variant'] == 'Control']['Time Spent']
VB_TS = df[df['Variant'] == 'Variant B']['Time Spent']

t_stat, p_val = stats.ttest_ind(Control_TS, VB_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -8.174237395991806
# P-value: 1.496358076285182e-15

# %%
l1_group = df[df['Location'] == 'Location1']
l2_group = df[df['Location'] == 'Location2']
l3_group = df[df['Location'] == 'Location3']

# %%
l1_group_C_CTR = l1_group[l1_group['Variant'] == 'Control']['CTR']
l1_group_A_CTR = l1_group[l1_group['Variant'] == 'Variant A']['CTR']

t_stat, p_val = stats.ttest_ind(l1_group_C_CTR, l1_group_A_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -8.57746443828315
# P-value: 2.0976781944166036e-15

# %%
#######
l1_group_C_CTR = l1_group[l1_group['Variant'] == 'Control']['CTR']
l1_group_B_CTR = l1_group[l1_group['Variant'] == 'Variant B']['CTR']

t_stat, p_val = stats.ttest_ind(l1_group_C_CTR, l1_group_B_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -3.3103787506434785
# P-value: 0.0010822864521394416

# %%
l2_group_C_CTR = l2_group[l2_group['Variant'] == 'Control']['CTR']
l2_group_A_CTR = l2_group[l2_group['Variant'] == 'Variant A']['CTR']

t_stat, p_val = stats.ttest_ind(l2_group_C_CTR, l2_group_A_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -7.477500779389085
# P-value: 1.3733460828153514e-12

# %%
#######
l2_group_C_CTR = l2_group[l2_group['Variant'] == 'Control']['CTR']
l2_group_B_CTR = l2_group[l2_group['Variant'] == 'Variant B']['CTR']

t_stat, p_val = stats.ttest_ind(l2_group_C_CTR, l2_group_B_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -2.8889458592932735
# P-value: 0.004249935452773755

# %%
l3_group_C_CTR = l3_group[l3_group['Variant'] == 'Control']['CTR']
l3_group_A_CTR = l3_group[l3_group['Variant'] == 'Variant A']['CTR']

t_stat, p_val = stats.ttest_ind(l3_group_C_CTR, l3_group_A_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -8.340963346393627
# P-value: 9.718704550164517e-15

# %%
l3_group_C_CTR = l3_group[l3_group['Variant'] == 'Control']['CTR']
l3_group_B_CTR = l3_group[l3_group['Variant'] == 'Variant B']['CTR']

t_stat, p_val = stats.ttest_ind(l3_group_C_CTR, l3_group_B_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -5.150621764177607
# P-value: 5.880128361679234e-07

# %%
l1_group_C_TS = l1_group[l1_group['Variant'] == 'Control']['Time Spent']
l1_group_A_TS = l1_group[l1_group['Variant'] == 'Variant A']['Time Spent']

t_stat, p_val = stats.ttest_ind(l1_group_C_TS, l1_group_A_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -7.406752439251856
# P-value: 3.057555232531658e-12

# %%
l1_group_C_TS = l1_group[l1_group['Variant'] == 'Control']['Time Spent']
l1_group_B_TS = l1_group[l1_group['Variant'] == 'Variant B']['Time Spent']

t_stat, p_val = stats.ttest_ind(l1_group_C_TS, l1_group_B_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -6.007022485418614
# P-value: 7.363085692632088e-09

# %%
l2_group_C_TS = l2_group[l2_group['Variant'] == 'Control']['Time Spent']
l2_group_A_TS = l2_group[l2_group['Variant'] == 'Variant A']['Time Spent']

t_stat, p_val = stats.ttest_ind(l2_group_C_TS, l2_group_A_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -6.730038639935233
# P-value: 1.2100132721624506e-10

# %%
l2_group_C_TS = l2_group[l2_group['Variant'] == 'Control']['Time Spent']
l2_group_B_TS = l2_group[l2_group['Variant'] == 'Variant B']['Time Spent']

t_stat, p_val = stats.ttest_ind(l2_group_C_TS, l2_group_B_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -4.078748002006866
# P-value: 6.32172451710319e-05

# %%
l3_group_C_TS = l3_group[l3_group['Variant'] == 'Control']['Time Spent']
l3_group_A_TS = l3_group[l3_group['Variant'] == 'Variant A']['Time Spent']

t_stat, p_val = stats.ttest_ind(l3_group_C_TS, l3_group_A_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -6.858267316404469
# P-value: 7.657273648543658e-11

# %%
l3_group_C_TS = l3_group[l3_group['Variant'] == 'Control']['Time Spent']
l3_group_B_TS = l3_group[l3_group['Variant'] == 'Variant B']['Time Spent']

t_stat, p_val = stats.ttest_ind(l3_group_C_TS, l3_group_B_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -3.977985105001808
# P-value: 9.511838328856589e-05

# %%
d1_group = df[df['Device'] == 'Device1']
d2_group = df[df['Device'] == 'Device2']
d3_group = df[df['Device'] == 'Device3']

# %%
d1_group_C_CTR = d1_group[d1_group['Variant'] == 'Control']['CTR']
d1_group_A_CTR = d1_group[d1_group['Variant'] == 'Variant A']['CTR']

t_stat, p_val = stats.ttest_ind(d1_group_C_CTR, d1_group_A_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -9.310995151550445
# P-value: 1.3109328277932585e-17

# %%
#######
d1_group_C_CTR = d1_group[d1_group['Variant'] == 'Control']['CTR']
d1_group_B_CTR = d1_group[d1_group['Variant'] == 'Variant B']['CTR']

t_stat, p_val = stats.ttest_ind(d1_group_C_CTR, d1_group_B_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -3.0018646841979515
# P-value: 0.0030101066626346987

# %%
d1_group_C_TS = d1_group[d1_group['Variant'] == 'Control']['Time Spent']
d1_group_A_TS = d1_group[d1_group['Variant'] == 'Variant A']['Time Spent']

t_stat, p_val = stats.ttest_ind(d1_group_C_TS, d1_group_A_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -8.139968377238139
# P-value: 2.868071261776281e-14

# %%
d1_group_C_TS = d1_group[d1_group['Variant'] == 'Control']['Time Spent']
d1_group_B_TS = d1_group[d1_group['Variant'] == 'Variant B']['Time Spent']

t_stat, p_val = stats.ttest_ind(d1_group_C_TS, d1_group_B_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -4.850386516005883
# P-value: 2.4048374925930364e-06

# %%
d2_group_C_CTR = d2_group[d2_group['Variant'] == 'Control']['CTR']
d2_group_A_CTR = d2_group[d2_group['Variant'] == 'Variant A']['CTR']

t_stat, p_val = stats.ttest_ind(d2_group_C_CTR, d2_group_A_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -7.696835392781408
# P-value: 5.619553225906784e-13

# %%
d2_group_C_CTR = d2_group[d2_group['Variant'] == 'Control']['CTR']
d2_group_B_CTR = d2_group[d2_group['Variant'] == 'Variant B']['CTR']

t_stat, p_val = stats.ttest_ind(d2_group_C_CTR, d2_group_B_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -4.407347501828937
# P-value: 1.6057284355437423e-05

# %%
d2_group_C_TS = d2_group[d2_group['Variant'] == 'Control']['Time Spent']
d2_group_A_TS = d2_group[d2_group['Variant'] == 'Variant A']['Time Spent']

t_stat, p_val = stats.ttest_ind(d2_group_C_TS, d2_group_A_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -6.115678431539
# P-value: 4.724809705802487e-09

# %%
d2_group_C_TS = d2_group[d2_group['Variant'] == 'Control']['Time Spent']
d2_group_B_TS = d2_group[d2_group['Variant'] == 'Variant B']['Time Spent']

t_stat, p_val = stats.ttest_ind(d2_group_C_TS, d2_group_B_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -5.7253284429393885
# P-value: 3.2064912567018084e-08

# %%
d3_group_C_CTR = d3_group[d3_group['Variant'] == 'Control']['CTR']
d3_group_A_CTR = d3_group[d3_group['Variant'] == 'Variant A']['CTR']

t_stat, p_val = stats.ttest_ind(d3_group_C_CTR, d3_group_A_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -7.178588507148628
# P-value: 9.098279538862409e-12

# %%
######
d3_group_C_CTR = d3_group[d3_group['Variant'] == 'Control']['CTR']
d3_group_B_CTR = d3_group[d3_group['Variant'] == 'Variant B']['CTR']

t_stat, p_val = stats.ttest_ind(d3_group_C_CTR, d3_group_B_CTR)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -3.617536830289973
# P-value: 0.00036721585831430955

# %%
d3_group_C_TS = d3_group[d3_group['Variant'] == 'Control']['Time Spent']
d3_group_A_TS = d3_group[d3_group['Variant'] == 'Variant A']['Time Spent']

t_stat, p_val = stats.ttest_ind(d3_group_C_TS, d3_group_A_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -6.75475736483633
# P-value: 1.1050199219292424e-10

# %%
#######
d3_group_C_TS = d3_group[d3_group['Variant'] == 'Control']['Time Spent']
d3_group_B_TS = d3_group[d3_group['Variant'] == 'Variant B']['Time Spent']

t_stat, p_val = stats.ttest_ind(d3_group_C_TS, d3_group_B_TS)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: -3.436758766939727
# P-value: 0.0007011142726507586

# %% [markdown]
# Question 3\
# First, I drew some plots for the whole dataset to see if I could conclude any trend or relationship through the plots, and I did T-stats tests and P-value tests for them. But there is no explicit relationship between each variable with CTR and Time Spent. \
# Thus, I categorized the data into six groups. Three of them are categorized by location, and three of them are by device. And I did some T-stats tests and P-value tests to find the implicit relationship of each variable with CTR and time spent.\
# The major finding is that Variant B can positively affect this applicant's CTR and time spents. Because I did 24 tests to verify the significant influence of different location and device in CTR and time spent. My tests show that in Location 1 and 2, regardless of device, Variant B significantly impacts CTR, and people using Device 1 and 3 with Variant B also show the trend. And Device 3 has a significant impact on Time Spent.\
# In conclusion, Variant B will be the optimun chioce for the exisiting feature.

# %% [markdown]
# Question 4\
# First I will focus on the users of Location 1, 3 and Device1, 3, because they are the most affected by the new feature through testing.\
# Secondly, I think that no matter where they are and what device they use, they will be affected by Variant B. So this conclusion can be generalized to all users. Because the sample size of the data is not very large, some hidden effects are not fully reflected in the data.\
# Therefore, I would recommend the company to update Variant B and emphasize that Variant B can make users stay longer and have higher CTR, thus gaining more users' time and attention.\
