# %%
import pandas  as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/lilfakeS/schulich_data_science/main/titanic_train.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex
# count    891.000000  891.000000  891.000000                      891   891  \
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
titanic.drop('Name', axis=1, inplace=True)
titanic.drop('Cabin',axis= 1 , inplace = True)

# %%
titanic.dropna(subset=['Embarked'], inplace= True)

# %%
titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass   Sex         Age       SibSp
# count    889.000000  889.000000  889.000000   889  712.000000  889.000000  \
# unique          NaN         NaN         NaN     2         NaN         NaN
# top             NaN         NaN         NaN  male         NaN         NaN
# freq            NaN         NaN         NaN   577         NaN         NaN
# mean     446.000000    0.382452    2.311586   NaN   29.642093    0.524184
# std      256.998173    0.486260    0.834700   NaN   14.492933    1.103705
# min        1.000000    0.000000    1.000000   NaN    0.420000    0.000000
# 25%      224.000000    0.000000    2.000000   NaN   20.000000    0.000000
# 50%      446.000000    0.000000    3.000000   NaN   28.000000    0.000000
# 75%      668.000000    1.000000    3.000000   NaN   38.000000    1.000000
# max      891.000000    1.000000    3.000000   NaN   80.000000    8.000000
#
#              Parch  Ticket        Fare Embarked
# ...

# %%
mean_age = titanic['Age'].mean()

# %%
titanic['Age'].fillna(mean_age, inplace=True)

# %%
titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass   Sex         Age       SibSp
# count    889.000000  889.000000  889.000000   889  889.000000  889.000000  \
# unique          NaN         NaN         NaN     2         NaN         NaN
# top             NaN         NaN         NaN  male         NaN         NaN
# freq            NaN         NaN         NaN   577         NaN         NaN
# mean     446.000000    0.382452    2.311586   NaN   29.642093    0.524184
# std      256.998173    0.486260    0.834700   NaN   12.968346    1.103705
# min        1.000000    0.000000    1.000000   NaN    0.420000    0.000000
# 25%      224.000000    0.000000    2.000000   NaN   22.000000    0.000000
# 50%      446.000000    0.000000    3.000000   NaN   29.642093    0.000000
# 75%      668.000000    1.000000    3.000000   NaN   35.000000    1.000000
# max      891.000000    1.000000    3.000000   NaN   80.000000    8.000000
#
#              Parch  Ticket        Fare Embarked
# ...

# %%
titanic.drop('PassengerId', axis=1, inplace=True)

# %%
cat_columns = ['Pclass','Sex','Ticket', 'Embarked']
num_columns = ['Age','SibSp','Parch','Fare']
target = 'Survived'

# %%
cat_transformer = OneHotEncoder(handle_unknown='ignore')
num_transformer = StandardScaler()
preprocessor = ColumnTransformer(transformers = [('cat',cat_transformer, cat_columns),
                                                 ('num', num_transformer, num_columns)])

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(titanic[cat_columns + num_columns], titanic['Survived'], test_size=0.3, random_state=111)

# %%
X_transformed = preprocessor.fit_transform(titanic[cat_columns + num_columns])
X_train_transformed = preprocessor.fit_transform(X_train)
X_test_transformed = preprocessor.fit_transform(X_test)

# %%
X_train_transformed.shape
# Out:
# (622, 522)

# %%
X_test_transformed.shape
# Out:
# (267, 249)

# %%
encoded_columns = list(preprocessor.named_transformers_['cat'].get_feature_names_out(cat_columns))
all_feat = num_columns + encoded_columns

X_train_transformed = pd.DataFrame(X_train_transformed, columns=all_feat)
X_test_transformed = pd.DataFrame(X_test_transformed, columns=all_feat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 4
#       1 encoded_columns = list(preprocessor.named_transformers_['cat'].get_feature_names_out(cat_columns))
#       2 all_feat = num_columns + encoded_columns
# ----> 4 X_train_transformed = pd.DataFrame(X_train_transformed, columns=all_feat)
#       5 X_test_transformed = pd.DataFrame(X_test_transformed, columns=all_feat)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:798, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     790         mgr = arrays_to_mgr(
#     791             arrays,
#     792             columns,
#    (...)
#     795             typ=manager,
#     796         )
#     797     else:
# --> 798         mgr = ndarray_to_mgr(
#     799             data,
#     800             index,
#     801             columns,
# ...
